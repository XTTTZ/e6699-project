# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import time
import numpy as np

np.random.seed(42)
torch.manual_seed(42)

device = torch.device(device='cuda' if torch.cuda.is_available() else 'cpu')  
print(device)
# Out:
# cuda

# %%
# 加载 MNIST 数据集
train_dataset = torchvision.datasets.MNIST(
    root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = torchvision.datasets.MNIST(
    root='./data', train=False, transform=transforms.ToTensor())

# %%
# 超参数设置
input_size = 784  # MNIST 图像大小为 28x28，展平后为 784
num_classes = 10  # 类别数
num_epochs = 50
batch_size = 20000
momentum=0.9
learning_rate = 5e-4

class Model(nn.Module):
    def __init__(self, input_size, num_classes):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(input_size, 1000, bias=True)
        self.fc2 = nn.Linear(1000, 1000, bias=True)
        self.fc3 = nn.Linear(1000, num_classes, bias=True)


    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
model = Model(input_size, num_classes).to(device)
print(model)
def reset_parameters(m):
    if isinstance(m, Model):
        for layer in m.children():
            if isinstance(layer, nn.Linear):
                nn.init.xavier_normal_(layer.weight)
                nn.init.zeros_(layer.bias)
# Out:
# Model(
#   (fc1): Linear(in_features=784, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=1000, bias=True)
#   (fc3): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
# 数据加载器
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=False)

criterion = nn.CrossEntropyLoss()

optimizers = {
    'SGDNesterov': torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, nesterov=True),
    'Adam': torch.optim.Adam(model.parameters(), lr=learning_rate),
    'Adagrad': torch.optim.Adagrad(model.parameters(), lr=learning_rate),
    'AdaDelta': torch.optim.Adadelta(model.parameters(), lr=learning_rate),
    'RMSProp': torch.optim.RMSprop(model.parameters(), lr=learning_rate)
}

training_losses = {name: [] for name in optimizers.keys()}
for name, optimizer in optimizers.items():
    # 训练模型
    print(f"\nTraining with {name} optimizer")
    model.apply(reset_parameters)
    for epoch in range(num_epochs):
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            images = images.reshape(-1, 28*28).to(device)
            labels = labels.to(device)

            # 前向传播
            outputs = model(images)
            loss = criterion(outputs, labels)
            training_losses[name].append(loss.item())
            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Training with SGDNesterov optimizer
# Epoch [1/50], Loss: 2.3425
# Epoch [2/50], Loss: 2.3358
# Epoch [3/50], Loss: 2.3251
# Epoch [4/50], Loss: 2.3141
# Epoch [5/50], Loss: 2.3015
# Epoch [6/50], Loss: 2.2902
# Epoch [7/50], Loss: 2.2761
# Epoch [8/50], Loss: 2.2635
# Epoch [9/50], Loss: 2.2488
# Epoch [10/50], Loss: 2.2340
# Epoch [11/50], Loss: 2.2205
# Epoch [12/50], Loss: 2.2065
# Epoch [13/50], Loss: 2.1921
# Epoch [14/50], Loss: 2.1818
# Epoch [15/50], Loss: 2.1667
# Epoch [16/50], Loss: 2.1538
# Epoch [17/50], Loss: 2.1432
# Epoch [18/50], Loss: 2.1299
# Epoch [19/50], Loss: 2.1175
# Epoch [20/50], Loss: 2.1053
# Epoch [21/50], Loss: 2.0957
# Epoch [22/50], Loss: 2.0818
# Epoch [23/50], Loss: 2.0698
# Epoch [24/50], Loss: 2.0563
# Epoch [25/50], Loss: 2.0424
# Epoch [26/50], Loss: 2.0333
# Epoch [27/50], Loss: 2.0207
# Epoch [28/50], Loss: 2.0103
# Epoch [29/50], Loss: 1.9973
# Epoch [30/50], Loss: 1.9851
# Epoch [31/50], Loss: 1.9720
# Epoch [32/50], Loss: 1.9630
# Epoch [33/50], Loss: 1.9480
# Epoch [34/50], Loss: 1.9370
# Epoch [35/50], Loss: 1.9243
# Epoch [36/50], Loss: 1.9139
# Epoch [37/50], Loss: 1.9032
# Epoch [38/50], Loss: 1.8916
# Epoch [39/50], Loss: 1.8844
# Epoch [40/50], Loss: 1.8671
# Epoch [41/50], Loss: 1.8563
# Epoch [42/50], Loss: 1.8473
# Epoch [43/50], Loss: 1.8331
# Epoch [44/50], Loss: 1.8203
# Epoch [45/50], Loss: 1.8070
# Epoch [46/50], Loss: 1.7953
# Epoch [47/50], Loss: 1.7842
# Epoch [48/50], Loss: 1.7735
# Epoch [49/50], Loss: 1.7657
# Epoch [50/50], Loss: 1.7531
#
# Training with Adam optimizer
# Epoch [1/50], Loss: 1.7613
# Epoch [2/50], Loss: 1.0711
# Epoch [3/50], Loss: 0.6432
# Epoch [4/50], Loss: 0.4546
# Epoch [5/50], Loss: 0.3714
# Epoch [6/50], Loss: 0.3330
# Epoch [7/50], Loss: 0.3115
# Epoch [8/50], Loss: 0.2896
# Epoch [9/50], Loss: 0.2663
# Epoch [10/50], Loss: 0.2396
# Epoch [11/50], Loss: 0.2239
# Epoch [12/50], Loss: 0.2170
# Epoch [13/50], Loss: 0.1988
# Epoch [14/50], Loss: 0.1888
# Epoch [15/50], Loss: 0.1747
# Epoch [16/50], Loss: 0.1716
# Epoch [17/50], Loss: 0.1541
# Epoch [18/50], Loss: 0.1550
# Epoch [19/50], Loss: 0.1507
# Epoch [20/50], Loss: 0.1308
# Epoch [21/50], Loss: 0.1306
# Epoch [22/50], Loss: 0.1247
# Epoch [23/50], Loss: 0.1155
# Epoch [24/50], Loss: 0.1150
# Epoch [25/50], Loss: 0.1041
# Epoch [26/50], Loss: 0.1034
# Epoch [27/50], Loss: 0.0998
# Epoch [28/50], Loss: 0.0958
# Epoch [29/50], Loss: 0.0902
# Epoch [30/50], Loss: 0.0828
# Epoch [31/50], Loss: 0.0840
# Epoch [32/50], Loss: 0.0785
# Epoch [33/50], Loss: 0.0747
# Epoch [34/50], Loss: 0.0730
# Epoch [35/50], Loss: 0.0697
# Epoch [36/50], Loss: 0.0673
# Epoch [37/50], Loss: 0.0682
# Epoch [38/50], Loss: 0.0602
# Epoch [39/50], Loss: 0.0606
# Epoch [40/50], Loss: 0.0551
# Epoch [41/50], Loss: 0.0544
# Epoch [42/50], Loss: 0.0525
# Epoch [43/50], Loss: 0.0475
# Epoch [44/50], Loss: 0.0490
# Epoch [45/50], Loss: 0.0454
# Epoch [46/50], Loss: 0.0436
# Epoch [47/50], Loss: 0.0451
# Epoch [48/50], Loss: 0.0425
# Epoch [49/50], Loss: 0.0400
# Epoch [50/50], Loss: 0.0382
#
# Training with Adagrad optimizer
# Epoch [1/50], Loss: 1.8247
# Epoch [2/50], Loss: 1.3284
# Epoch [3/50], Loss: 1.0180
# Epoch [4/50], Loss: 0.8324
# Epoch [5/50], Loss: 0.6993
# Epoch [6/50], Loss: 0.6272
# Epoch [7/50], Loss: 0.5703
# Epoch [8/50], Loss: 0.5211
# Epoch [9/50], Loss: 0.4890
# Epoch [10/50], Loss: 0.4662
# Epoch [11/50], Loss: 0.4432
# Epoch [12/50], Loss: 0.4226
# Epoch [13/50], Loss: 0.4043
# Epoch [14/50], Loss: 0.3870
# Epoch [15/50], Loss: 0.3792
# Epoch [16/50], Loss: 0.3635
# Epoch [17/50], Loss: 0.3607
# Epoch [18/50], Loss: 0.3452
# Epoch [19/50], Loss: 0.3418
# Epoch [20/50], Loss: 0.3343
# Epoch [21/50], Loss: 0.3228
# Epoch [22/50], Loss: 0.3142
# Epoch [23/50], Loss: 0.3179
# Epoch [24/50], Loss: 0.3081
# Epoch [25/50], Loss: 0.3032
# Epoch [26/50], Loss: 0.2980
# Epoch [27/50], Loss: 0.2971
# Epoch [28/50], Loss: 0.2928
# Epoch [29/50], Loss: 0.2836
# Epoch [30/50], Loss: 0.2865
# Epoch [31/50], Loss: 0.2806
# Epoch [32/50], Loss: 0.2829
# Epoch [33/50], Loss: 0.2649
# Epoch [34/50], Loss: 0.2680
# Epoch [35/50], Loss: 0.2738
# Epoch [36/50], Loss: 0.2665
# Epoch [37/50], Loss: 0.2607
# Epoch [38/50], Loss: 0.2610
# Epoch [39/50], Loss: 0.2536
# Epoch [40/50], Loss: 0.2632
# Epoch [41/50], Loss: 0.2492
# Epoch [42/50], Loss: 0.2507
# Epoch [43/50], Loss: 0.2422
# Epoch [44/50], Loss: 0.2412
# Epoch [45/50], Loss: 0.2429
# Epoch [46/50], Loss: 0.2366
# Epoch [47/50], Loss: 0.2361
# Epoch [48/50], Loss: 0.2332
# Epoch [49/50], Loss: 0.2386
# Epoch [50/50], Loss: 0.2371
#
# Training with AdaDelta optimizer
# Epoch [1/50], Loss: 2.3278
# Epoch [2/50], Loss: 2.3236
# Epoch [3/50], Loss: 2.3213
# Epoch [4/50], Loss: 2.3223
# Epoch [5/50], Loss: 2.3204
# Epoch [6/50], Loss: 2.3162
# Epoch [7/50], Loss: 2.3168
# Epoch [8/50], Loss: 2.3158
# Epoch [9/50], Loss: 2.3147
# Epoch [10/50], Loss: 2.3095
# Epoch [11/50], Loss: 2.3102
# Epoch [12/50], Loss: 2.3098
# Epoch [13/50], Loss: 2.3068
# Epoch [14/50], Loss: 2.3046
# Epoch [15/50], Loss: 2.3044
# Epoch [16/50], Loss: 2.3043
# Epoch [17/50], Loss: 2.3012
# Epoch [18/50], Loss: 2.2986
# Epoch [19/50], Loss: 2.2987
# Epoch [20/50], Loss: 2.2972
# Epoch [21/50], Loss: 2.2946
# Epoch [22/50], Loss: 2.2950
# Epoch [23/50], Loss: 2.2916
# Epoch [24/50], Loss: 2.2903
# Epoch [25/50], Loss: 2.2881
# Epoch [26/50], Loss: 2.2847
# Epoch [27/50], Loss: 2.2859
# Epoch [28/50], Loss: 2.2835
# Epoch [29/50], Loss: 2.2822
# Epoch [30/50], Loss: 2.2792
# Epoch [31/50], Loss: 2.2790
# Epoch [32/50], Loss: 2.2769
# Epoch [33/50], Loss: 2.2780
# Epoch [34/50], Loss: 2.2752
# Epoch [35/50], Loss: 2.2723
# Epoch [36/50], Loss: 2.2710
# Epoch [37/50], Loss: 2.2688
# Epoch [38/50], Loss: 2.2680
# Epoch [39/50], Loss: 2.2672
# Epoch [40/50], Loss: 2.2670
# Epoch [41/50], Loss: 2.2634
# Epoch [42/50], Loss: 2.2626
# Epoch [43/50], Loss: 2.2612
# Epoch [44/50], Loss: 2.2585
# Epoch [45/50], Loss: 2.2574
# Epoch [46/50], Loss: 2.2556
# Epoch [47/50], Loss: 2.2549
# Epoch [48/50], Loss: 2.2522
# Epoch [49/50], Loss: 2.2537
# Epoch [50/50], Loss: 2.2505
#
# Training with RMSProp optimizer
# Epoch [1/50], Loss: 2.9190
# Epoch [2/50], Loss: 1.0649
# Epoch [3/50], Loss: 0.7287
# Epoch [4/50], Loss: 0.5969
# Epoch [5/50], Loss: 0.3310
# Epoch [6/50], Loss: 0.3318
# Epoch [7/50], Loss: 0.3324
# Epoch [8/50], Loss: 0.2418
# Epoch [9/50], Loss: 0.2223
# Epoch [10/50], Loss: 0.2028
# Epoch [11/50], Loss: 0.2023
# Epoch [12/50], Loss: 0.2408
# Epoch [13/50], Loss: 0.2621
# Epoch [14/50], Loss: 0.1639
# Epoch [15/50], Loss: 0.1541
# Epoch [16/50], Loss: 0.1460
# Epoch [17/50], Loss: 0.1430
# Epoch [18/50], Loss: 0.1389
# Epoch [19/50], Loss: 0.1408
# Epoch [20/50], Loss: 0.1442
# Epoch [21/50], Loss: 0.2015
# Epoch [22/50], Loss: 0.1249
# Epoch [23/50], Loss: 0.1146
# Epoch [24/50], Loss: 0.1089
# Epoch [25/50], Loss: 0.1009
# Epoch [26/50], Loss: 0.0968
# Epoch [27/50], Loss: 0.0970
# Epoch [28/50], Loss: 0.1070
# Epoch [29/50], Loss: 0.1276
# Epoch [30/50], Loss: 0.0943
# Epoch [31/50], Loss: 0.0835
# Epoch [32/50], Loss: 0.0809
# Epoch [33/50], Loss: 0.0845
# Epoch [34/50], Loss: 0.0819
# Epoch [35/50], Loss: 0.0841
# Epoch [36/50], Loss: 0.0808
# Epoch [37/50], Loss: 0.0702
# Epoch [38/50], Loss: 0.0680
# Epoch [39/50], Loss: 0.0682
# Epoch [40/50], Loss: 0.0656
# Epoch [41/50], Loss: 0.0709
# Epoch [42/50], Loss: 0.1062
# Epoch [43/50], Loss: 0.1520
# Epoch [44/50], Loss: 0.0948
# Epoch [45/50], Loss: 0.0624
# Epoch [46/50], Loss: 0.0576
# Epoch [47/50], Loss: 0.0590
# Epoch [48/50], Loss: 0.0573
# Epoch [49/50], Loss: 0.0533
# Epoch [50/50], Loss: 0.0518

# %%
plt.figure(figsize=(10, 5))
for name, losses in training_losses.items():
    plt.plot(losses, label=name)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.ylim(0,5)
plt.xlim(0,100)
plt.show()
